# %%
import pandas as pd
import os
data =  pd.read_csv(os.path.join("all_quotes.csv"))
data = data.drop('Other Tags', axis=1)
data.dropna(inplace= True)
print(data['Main Tag'].value_counts())
data.info()
data =data[data['Quote'].str.contains('r[^\{IsLatin}]')]
data =data[data['Author'].str.match('.*')]
data.rename(columns = {"Unnamed: 0":"Id"}, inplace = True)
data = data[data['Quote'].str.split().str.len().lt(15)]
data = data[data['Author'].str.split().str.len().lt(9)]
data['Author'] = data['Author'].str[3:]
data.to_csv('out.csv', index=False)
data.info()
print(data['Main Tag'].value_counts())
data.head()
# Out:
# inspiration    2938
# success        2930
# time           2902
# happiness      2885
# truth          2880
# death          2822
# science        2814
# love           2813
# romance        2751
# poetry         2666
# Name: Main Tag, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28401 entries, 0 to 29999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  28401 non-null  int64
#  1   Quote       28401 non-null  object
#  2   Author      28401 non-null  object
#  3   Main Tag    28401 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6237 entries, 4 to 29995
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        6237 non-null   int64
#  1   Quote     6237 non-null   object
#  2   Author    6237 non-null   object
#  3   Main Tag  6237 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 243.6+ KB
# poetry         1068
# success         737
# inspiration     699
# time            676
# truth           634
# happiness       613
# death           531
# love            510
# romance         477
# science         292
# Name: Main Tag, dtype: int64
#     Id                                              Quote  \
# 4    4  “Truths are written, never said... Lines are d...
# 5    5  “Extraordinary magic is woven through ordinary...
# 6    6  “You’re supposed to pinch yourself – not the o...
# 14  14                      “Ever peaceful be you slumber
# 18  18                             “Mika: Were you happy?
#
#                               Author     Main Tag
# 4       olleen Hoover, Maybe Someday       poetry
# 5                   my Leigh Mercree  inspiration
# 6            icki Elson, Three Daves      romance
# 14  ugh your days were few in number        death
# 18               o: I was so happy.”        truth
